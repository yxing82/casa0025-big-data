# %% [markdown]
# ## Initialisaiton

# %%
# %pip install duckdb leafmap

# %%
import duckdb
import leafmap

# %load_ext sql

# %%
con = duckdb.connect(database=':memory:')

# %%
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %%
# %% sql
#
# INSTALL httpfs;
# LOAD httpfs;

# %%
# we can use this cell to read files

# url = "https://storage.googleapis.com/qm2/CASA0025/nyc_data.db.zip"
#leafmap.download_file(url, unzip=True)

# %%
# if we read any .db file above
## con = duckdb.connect("nyc_data.db")

# %%
# %sql con

con.install_extension("spatial")
con.load_extension("spatial")

# %% [markdown]
# ## Answer questions with SQL queries
#
# If we only want to look up some data or tables,

# %%
# %%sql
#
# SELECT *
# FROM my_table
# WHERE id = 1;

# %% [markdown]
# We can also use `con.sql("""...""")` to get the same result

# %%
con.sql("""
SELECT * 
FROM my_table 
WHERE id = 1;
""")
